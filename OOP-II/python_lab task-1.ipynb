# %%
print("Hello")
# Out:
# Hello

# %%
name = "Md Abir Ahmed Porosh"
print(name)
# Out:
# Md Abir Ahmed Porosh

# %%
a = 15
b = 6
add = a + b

sub = a - b

mul = a * b

mod = a % b

p = a ** b
print(add)
print(sub)
print(mul)
print(mod)
print(p)
# Out:
# 21
# 9
# 90
# 3
# 11390625

# %%
a = "5"
b = "7"

add = a+b
print(f'String addition : {add}')

num = int(a) + int(b)
print(f'Integer Number : {num}')
# Out:
# String addition : 57
# Integer Number : 12

# %% [markdown]
# Bitwise operator

# %%
a = 20
b = 6

print(a & b)
print(a | b)
print(~a)
print(a ^ b)
print(a >> 2)
print(a << 2)
# Out:
# 4
# 22
# -21
# 18
# 5
# 80

# %% [markdown]
# if elif statement

# %%
a = input("Enter the 1st number :")
b = input("Enter the 2nd number :")
if(a > b):
  print(f'Gratest number{a}')
else:
  print(f'Gratest number{b}')
# Out:
# Enter the 1st number :12
# Enter the 2nd number :14
# Smallest number14

# %% [markdown]
# loop

# %%
count = 5
while count !=0 :
  print("Hello World")
  count-=1
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
count = 0
for count in range(0,10,2):
  print(count)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
count = 0
for count in range(0,10):
  if(count == 7) :
    break
  print(count)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# Function

# %%
def number(x):
  if x%2==0 :
    print(f'Even Number : {x}')
  else :
    print(f'Odd Number : {x}')

number(10)
number(9)
# Out:
# Even Number : 10
# Odd Number : 9
